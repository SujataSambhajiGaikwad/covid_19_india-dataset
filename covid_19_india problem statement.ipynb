# %% [markdown]
# ## Import Librares

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading Dataset

# %%
data=pd.read_csv(r"C:\Users\sujat\Downloads\DataSets\covid_19_india.csv")
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# # Q1) Preprosing the data and remove the null values and replace the particular state.

# %%
data.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %% [markdown]
# # Q2) Find the average death count in Maharastra,Karnataka and Kerala.

# %%
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1=data.iloc[:,[3,7]]
data1
# Out:
#       State/UnionTerritory  Deaths
# 0                   Kerala       0
# 1                   Kerala       0
# 2                   Kerala       0
# 3                   Kerala       0
# 4                   Kerala       0
# ...                    ...     ...
# 18105            Telangana    3831
# 18106              Tripura     773
# 18107          Uttarakhand    7368
# 18108        Uttar Pradesh   22775
# 18109          West Bengal   18252
#
# [18110 rows x 2 columns]

# %%
data2=data1.loc[(data1["State/UnionTerritory"]=="Kerala")|(data1["State/UnionTerritory"]=="Karnataka")|(data1["State/UnionTerritory"]=="Maharashtra")]
data2
# Out:
#       State/UnionTerritory  Deaths
# 0                   Kerala       0
# 1                   Kerala       0
# 2                   Kerala       0
# 3                   Kerala       0
# 4                   Kerala       0
# ...                    ...     ...
# 18054               Kerala   17852
# 18058          Maharashtra  134064
# 18089            Karnataka   36848
# 18090               Kerala   18004
# 18094          Maharashtra  134201
#
# [1600 rows x 2 columns]

# %%
data2["State/UnionTerritory"].unique()
# Out:
# array(['Kerala', 'Karnataka', 'Maharashtra'], dtype=object)

# %%
data2["Deaths"].mean()
# Out:
# 19799.606875

# %% [markdown]
# # Q3) Find the top 5 state in jan 20 to jun 20 and count death and confirmed.

# %%
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1=data.iloc[:,[1,3,7,8]]
data1
# Out:
#              Date State/UnionTerritory  Deaths  Confirmed
# 0      2020-01-30               Kerala       0          1
# 1      2020-01-31               Kerala       0          1
# 2      2020-02-01               Kerala       0          2
# 3      2020-02-02               Kerala       0          3
# 4      2020-02-03               Kerala       0          3
# ...           ...                  ...     ...        ...
# 18105  2021-08-11            Telangana    3831     650353
# 18106  2021-08-11              Tripura     773      80660
# 18107  2021-08-11          Uttarakhand    7368     342462
# 18108  2021-08-11        Uttar Pradesh   22775    1708812
# 18109  2021-08-11          West Bengal   18252    1534999
#
# [18110 rows x 4 columns]

# %%
data1["Date"].unique()
# Out:
# array(['2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#        '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#        '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#        '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#        '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#        '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#        '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
#        '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29',
# ...

# %%
data2=data1.loc[(data1["Date"]<='2020-06-30')]
data2
# Out:
#             Date              State/UnionTerritory  Deaths  Confirmed
# 0     2020-01-30                            Kerala       0          1
# 1     2020-01-31                            Kerala       0          1
# 2     2020-02-01                            Kerala       0          2
# 3     2020-02-02                            Kerala       0          3
# 4     2020-02-03                            Kerala       0          3
# ...          ...                               ...     ...        ...
# 3598  2020-06-30                           Tripura       1       1380
# 3599  2020-06-30                       Uttarakhand      39       2831
# 3600  2020-06-30                     Uttar Pradesh     672      22828
# 3601  2020-06-30                       West Bengal     653      17907
# 3602  2020-06-30  Cases being reassigned to states       0       7004
#
# [3603 rows x 4 columns]

# %%
data2["State/UnionTerritory"].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu'],
#       dtype=object)

# %%
data2["State/UnionTerritory"].value_counts()
# Out:
# Kerala                                      153
# Delhi                                       121
# Telengana                                   121
# Rajasthan                                   120
# Uttar Pradesh                               119
# Haryana                                     119
# Ladakh                                      116
# Tamil Nadu                                  116
# Punjab                                      114
# Jammu and Kashmir                           114
# Maharashtra                                 114
# Karnataka                                   114
# Andhra Pradesh                              111
# Uttarakhand                                 108
# Odisha                                      107
# Puducherry                                  105
# West Bengal                                 105
# Chhattisgarh                                104
# Chandigarh                                  104
# Gujarat                                     103
# ...

# %%
data2["Deaths"].value_counts()
# Out:
# 0       1382
# 1        385
# 3        146
# 4        104
# 2        103
#         ...
# 309        1
# 2197       1
# 343        1
# 1007       1
# 653        1
# Name: Deaths, Length: 497, dtype: int64

# %% [markdown]
# # Q4) Find the most covid affected state in 2020

# %%
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1=data.iloc[:,[1,3]]
data1
# Out:
#              Date State/UnionTerritory
# 0      2020-01-30               Kerala
# 1      2020-01-31               Kerala
# 2      2020-02-01               Kerala
# 3      2020-02-02               Kerala
# 4      2020-02-03               Kerala
# ...           ...                  ...
# 18105  2021-08-11            Telangana
# 18106  2021-08-11              Tripura
# 18107  2021-08-11          Uttarakhand
# 18108  2021-08-11        Uttar Pradesh
# 18109  2021-08-11          West Bengal
#
# [18110 rows x 2 columns]

# %%
data2=data1.loc[(data1["Date"]<='2020-12-30')]
data2
# Out:
#              Date State/UnionTerritory
# 0      2020-01-30               Kerala
# 1      2020-01-31               Kerala
# 2      2020-02-01               Kerala
# 3      2020-02-02               Kerala
# 4      2020-02-03               Kerala
# ...           ...                  ...
# 10041  2020-12-30            Telengana
# 10042  2020-12-30              Tripura
# 10043  2020-12-30          Uttarakhand
# 10044  2020-12-30        Uttar Pradesh
# 10045  2020-12-30          West Bengal
#
# [10046 rows x 2 columns]

# %%
data2["State/UnionTerritory"].value_counts()
# Out:
# Kerala                                      336
# Delhi                                       304
# Telengana                                   304
# Rajasthan                                   303
# Uttar Pradesh                               302
# Haryana                                     302
# Ladakh                                      299
# Tamil Nadu                                  299
# Punjab                                      297
# Jammu and Kashmir                           297
# Maharashtra                                 297
# Karnataka                                   297
# Andhra Pradesh                              294
# Uttarakhand                                 291
# Odisha                                      290
# Puducherry                                  288
# West Bengal                                 288
# Chhattisgarh                                287
# Chandigarh                                  287
# Gujarat                                     286
# ...

# %% [markdown]
# # Q5) 2020 & 2021 compair the death and comfirmed

# %%
data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
data1=data.iloc[:,[1,7,8]]
data1
# Out:
#              Date  Deaths  Confirmed
# 0      2020-01-30       0          1
# 1      2020-01-31       0          1
# 2      2020-02-01       0          2
# 3      2020-02-02       0          3
# 4      2020-02-03       0          3
# ...           ...     ...        ...
# 18105  2021-08-11    3831     650353
# 18106  2021-08-11     773      80660
# 18107  2021-08-11    7368     342462
# 18108  2021-08-11   22775    1708812
# 18109  2021-08-11   18252    1534999
#
# [18110 rows x 3 columns]

# %%
data1["Deaths"].value_counts()
# Out:
# 0        1718
# 1         527
# 2         417
# 4         245
# 3         195
#          ...
# 12207       1
# 3799        1
# 50894       1
# 2761        1
# 18252       1
# Name: Deaths, Length: 6471, dtype: int64

# %%
data1["Deaths"].sum()
# Out:
# 73389005

# %%
data1["Confirmed"].sum()
# Out:
# 5451678687
